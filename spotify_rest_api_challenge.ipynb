# %% [markdown]
# ![spotify_logo](../img/spotify_logo.png)
#
# # Spotify REST API Challenge
#
# __What to listen?__
#
# Create your own playlist based on the related artists and their most popular tracks using the [Spotify REST API](https://developer.spotify.com/)

# %%
# Imports

# %pip install requests
import pandas as pd
import requests
from dotenv import dotenv_values
import random
import string
import requests
import webbrowser
# Out:
# Requirement already satisfied: requests in c:\users\arena\anaconda3\lib\site-packages (2.31.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\arena\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\arena\anaconda3\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\arena\anaconda3\lib\site-packages (from requests) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\arena\anaconda3\lib\site-packages (from requests) (2024.6.2)

# %% [markdown]
# ### Get access!!!
#
# Get your `client_id` and `client_secret` to generate your __token__ access

# %%
# Generate token with a POST request

client_id = '6751e65fd0c24f86a517bb2b55c5ed14'
client_secret = 'ecad297f713d42368132e34a7af54b64'
auth_url = 'https://accounts.spotify.com/api/token'

# %%
auth_response = requests.post(auth_url, {'grant_type': 'client_credentials',
                                         'client_id': client_id,
                                         'client_secret': client_secret}).json()

# %%
access_token = auth_response['access_token']
access_token
# Out:
# 'BQDP1UHPX6hsjicPRITDOX9d98C6onZI6ctbn1X0FjqDcZ2r5jrjuLXpvR7-GeyoNHqgMM7qh5DnFVBhG6AOl3iDwb2Rx57vzZYKFCwkDBPIRaDR494'

# %% [markdown]
# ### Set your main variables!!!
#
# Set the `base_uri` (i.e.: end-point), parameters and `headers` for your __GET__ operations

# %%
# Base end-point construction

base_url = 'https://api.spotify.com/v1/'
resource = 'artists/'

header_info = {'Authorization': 'Bearer {token}'.format(token=access_token)}

# %% [markdown]
# ### Create your new playlist!!!
#
# Use [`/related-artists`](https://developer.spotify.com/documentation/web-api/reference/#/operations/get-an-artists-related-artists) and [`/top-tracks`](https://developer.spotify.com/documentation/web-api/reference/#/operations/get-an-artists-top-tracks) in order to get the data that you need.
#
# __Here you have the different artists to start with:__
#
# - __Option 1:__ 0L8ExT028jH3ddEcZwqJJ5
#
# - __Option 2:__ 4Y7tXHSEejGu1vQ9bwDdXW
#
# - __Option 3:__ 6FBDaR13swtiWwGhX1WQsP
#
# - __Option 4:__ 0kyQwKHCZnKE7kTXkxXjrB
#
# - __Option 5:__ 2d0hyoQ5ynDBnkvAbJKORj
#
# - __Option 6:__ 3bgsNtcf5d5h9jbQbohfBK
#
# - __Option 7:__ 7mWCSSOYqm4E9mB7V4ot6S
#
# - __Option 8:__ 64KEffDW9EtZ1y2vBYgq8T
#
# - __Option 9:__ 4k1ELeJKT1ISyDv8JivPpB
#
# - __Option 10:__ 4Z8W4fKeB5YxbusRsdQVPb
#
# - __Option 11:__ 26dSoYclwsYLMAKD3tpOr4
#
# - __Option 12:__ 7y97mc3bZRFXzT2szRM4L4
#
# - __Option 13:__ 1w5Kfo2jwwIPruYS2UWh56
#
#
# > Remember to check the [Requests](https://requests.readthedocs.io/en/latest/) library docs!!!
#
# ---

# %%
# Here you can complete your endpoint URI
artist= "0L8ExT028jH3ddEcZwqJJ5"
full_endpoint = base_url + resource + artist
full_endpoint
# Out:
# 'https://api.spotify.com/v1/artists/0L8ExT028jH3ddEcZwqJJ5'

# %%
# Start building your playlist!!!
relres = requests.get(full_endpoint + '/related-artists', headers=header_info)
related = relres.json()

# %%
df = pd.json_normalize(related['artists'])
df.head()
# Out:
#                                               genres  \
# 0  [alternative metal, alternative rock, modern r...
# 1  [alternative metal, alternative rock, consciou...
# 2  [alternative metal, alternative rock, grunge, ...
# 3  [alternative metal, alternative rock, classic ...
# 4  [alternative metal, alternative rock, grunge, ...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/artists/7jy3rLJdDQY...  7jy3rLJdDQY21OgRLCZ9sD
# 1  https://api.spotify.com/v1/artists/2d0hyoQ5ynD...  2d0hyoQ5ynDBnkvAbJKORj
# 2  https://api.spotify.com/v1/artists/2ziB7fzrXBo...  2ziB7fzrXBoh1HUPS6sVFn
# 3  https://api.spotify.com/v1/artists/1w5Kfo2jwwI...  1w5Kfo2jwwIPruYS2UWh56
# 4  https://api.spotify.com/v1/artists/40Yq4vzPs9V...  40Yq4vzPs9VNUrIBG5Jr2i
#
#                                               images  \
# 0  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 1  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 2  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 3  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 4  [{'height': 640, 'url': 'https://i.scdn.co/ima...
#
#                        name  popularity    type  \
# 0              Foo Fighters          77  artist
# 1  Rage Against The Machine          70  artist
# 2                Audioslave          67  artist
# 3                 Pearl Jam          74  artist
# 4     The Smashing Pumpkins          71  artist
#
#                                      uri  \
# 0  spotify:artist:7jy3rLJdDQY21OgRLCZ9sD
# 1  spotify:artist:2d0hyoQ5ynDBnkvAbJKORj
# 2  spotify:artist:2ziB7fzrXBoh1HUPS6sVFn
# 3  spotify:artist:1w5Kfo2jwwIPruYS2UWh56
# 4  spotify:artist:40Yq4vzPs9VNUrIBG5Jr2i
#
#                                external_urls.spotify followers.href  \
# 0  https://open.spotify.com/artist/7jy3rLJdDQY21O...           None
# 1  https://open.spotify.com/artist/2d0hyoQ5ynDBnk...           None
# 2  https://open.spotify.com/artist/2ziB7fzrXBoh1H...           None
# 3  https://open.spotify.com/artist/1w5Kfo2jwwIPru...           None
# 4  https://open.spotify.com/artist/40Yq4vzPs9VNUr...           None
#
#    followers.total
# 0         11777265
# 1          6011036
# 2          4500974
# 3          8798742
# 4          5104399

# %% [markdown]
# ---
#
# ### Bonus track!!!
#
# You can publish your own Playlist with [`/playlists`](https://developer.spotify.com/documentation/web-api/reference/#/operations/create-playlist) and [`/tracks`](https://developer.spotify.com/documentation/web-api/reference/#/operations/add-tracks-to-playlist).
#
# ![I quit](https://media.giphy.com/media/gui67fZ3xIneM/giphy.gif)

# %%
df.explode('genres').head()
# Out:
#               genres                                               href  \
# 0  alternative metal  https://api.spotify.com/v1/artists/7jy3rLJdDQY...
# 0   alternative rock  https://api.spotify.com/v1/artists/7jy3rLJdDQY...
# 0        modern rock  https://api.spotify.com/v1/artists/7jy3rLJdDQY...
# 0     permanent wave  https://api.spotify.com/v1/artists/7jy3rLJdDQY...
# 0        post-grunge  https://api.spotify.com/v1/artists/7jy3rLJdDQY...
#
#                        id                                             images  \
# 0  7jy3rLJdDQY21OgRLCZ9sD  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 0  7jy3rLJdDQY21OgRLCZ9sD  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 0  7jy3rLJdDQY21OgRLCZ9sD  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 0  7jy3rLJdDQY21OgRLCZ9sD  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 0  7jy3rLJdDQY21OgRLCZ9sD  [{'height': 640, 'url': 'https://i.scdn.co/ima...
#
#            name  popularity    type                                    uri  \
# 0  Foo Fighters          77  artist  spotify:artist:7jy3rLJdDQY21OgRLCZ9sD
# 0  Foo Fighters          77  artist  spotify:artist:7jy3rLJdDQY21OgRLCZ9sD
# 0  Foo Fighters          77  artist  spotify:artist:7jy3rLJdDQY21OgRLCZ9sD
# 0  Foo Fighters          77  artist  spotify:artist:7jy3rLJdDQY21OgRLCZ9sD
# 0  Foo Fighters          77  artist  spotify:artist:7jy3rLJdDQY21OgRLCZ9sD
#
#                                external_urls.spotify followers.href  \
# 0  https://open.spotify.com/artist/7jy3rLJdDQY21O...           None
# 0  https://open.spotify.com/artist/7jy3rLJdDQY21O...           None
# 0  https://open.spotify.com/artist/7jy3rLJdDQY21O...           None
# 0  https://open.spotify.com/artist/7jy3rLJdDQY21O...           None
# 0  https://open.spotify.com/artist/7jy3rLJdDQY21O...           None
#
#    followers.total
# 0         11777265
# 0         11777265
# 0         11777265
# 0         11777265
# 0         11777265

# %%
# Bonus
new_endpoint= 'https://api.spotify.com/v1/artists/'


argument= '?market=GB'


url = new_endpoint + artist + '/top-tracks' + argument

url
# Out:
# 'https://api.spotify.com/v1/artists/0L8ExT028jH3ddEcZwqJJ5/top-tracks?market=GB'

# %% [markdown]
# ---

# %%
requests.get(url, headers=header_info).json()['tracks'][0]
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0L8ExT028jH3ddEcZwqJJ5'},
#     'href': 'https://api.spotify.com/v1/artists/0L8ExT028jH3ddEcZwqJJ5',
#     'id': '0L8ExT028jH3ddEcZwqJJ5',
#     'name': 'Red Hot Chili Peppers',
#     'type': 'artist',
#     'uri': 'spotify:artist:0L8ExT028jH3ddEcZwqJJ5'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/2Y9IRtehByVkegoD7TcLfi'},
#   'href': 'https://api.spotify.com/v1/albums/2Y9IRtehByVkegoD7TcLfi',
#   'id': '2Y9IRtehByVkegoD7TcLfi',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27394d08ab63e57b0cae74e8595',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0294d08ab63e57b0cae74e8595',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485194d08ab63e57b0cae74e8595',
#     'width': 64}],
#   'is_playable': True,
#   'name': 'Californication (Deluxe Edition)',
#   'release_date': '1999-06-08',
#   'release_date_precision': 'day',
#   'total_tracks': 18,
#   'type': 'album',
#   'uri': 'spotify:album:2Y9IRtehByVkegoD7TcLfi'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0L8ExT028jH3ddEcZwqJJ5'},
#    'href': 'https://api.spotify.com/v1/artists/0L8ExT028jH3ddEcZwqJJ5',
#    'id': '0L8ExT028jH3ddEcZwqJJ5',
#    'name': 'Red Hot Chili Peppers',
#    'type': 'artist',
#    'uri': 'spotify:artist:0L8ExT028jH3ddEcZwqJJ5'}],
#  'disc_number': 1,
#  'duration_ms': 329733,
#  'explicit': False,
#  'external_ids': {'isrc': 'USWB19900690'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/48UPSzbZjgc449aqz8bxox'},
#  'href': 'https://api.spotify.com/v1/tracks/48UPSzbZjgc449aqz8bxox',
#  'id': '48UPSzbZjgc449aqz8bxox',
#  'is_local': False,
#  'is_playable': True,
#  'name': 'Californication',
#  'popularity': 82,
#  'preview_url': 'https://p.scdn.co/mp3-preview/0fd595c5b63db10f4a99683f8248ea5d13700683?cid=6751e65fd0c24f86a517bb2b55c5ed14',
#  'track_number': 6,
#  'type': 'track',
#  'uri': 'spotify:track:48UPSzbZjgc449aqz8bxox'}

# %% [markdown]
# You can always try with the [wrapper](https://github.com/plamere/spotipy)!!!
#
# ![I quit](https://media.giphy.com/media/3oFzlXPvXYZ4q8VQOs/giphy.gif)

# %% [markdown]
# ---

# %%
top_tracks = pd.concat([pd.DataFrame(requests.get(new_endpoint + artista + '/top-tracks' + argument, 
                                                  headers=header_info).json()['tracks'])
                        for artista in df['id']])
top_tracks.head()
# Out:
#                                                album  \
# 0  {'album_type': 'album', 'artists': [{'external...
# 1  {'album_type': 'album', 'artists': [{'external...
# 2  {'album_type': 'album', 'artists': [{'external...
# 3  {'album_type': 'album', 'artists': [{'external...
# 4  {'album_type': 'album', 'artists': [{'external...
#
#                                              artists  disc_number  \
# 0  [{'external_urls': {'spotify': 'https://open.s...            1
# 1  [{'external_urls': {'spotify': 'https://open.s...            1
# 2  [{'external_urls': {'spotify': 'https://open.s...            1
# 3  [{'external_urls': {'spotify': 'https://open.s...            1
# 4  [{'external_urls': {'spotify': 'https://open.s...            1
#
#    duration_ms  explicit              external_ids  \
# 0       250546     False  {'isrc': 'USRW29600011'}
# 1       269373     False  {'isrc': 'USRW30700007'}
# 2       235293     False  {'isrc': 'USRW39900002'}
# 3       255626     False  {'isrc': 'USRW30500001'}
# 4       260026     False  {'isrc': 'USRW29600007'}
#
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/track/5U...
# 1  {'spotify': 'https://open.spotify.com/track/7x...
# 2  {'spotify': 'https://open.spotify.com/track/5O...
# 3  {'spotify': 'https://open.spotify.com/track/5F...
# 4  {'spotify': 'https://open.spotify.com/track/4d...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/tracks/5UWwZ5lm5PKu...  5UWwZ5lm5PKu6eKsHAGxOk
# 1  https://api.spotify.com/v1/tracks/7x8dCjCr0x6x...  7x8dCjCr0x6x2lXKujYD34
# 2  https://api.spotify.com/v1/tracks/5OQsiBsky2k2...  5OQsiBsky2k2kDKy2bX2eT
# 3  https://api.spotify.com/v1/tracks/5FZxsHWIvUsm...  5FZxsHWIvUsmSK1IAvm2pp
# 4  https://api.spotify.com/v1/tracks/4dVbhS6OiYvF...  4dVbhS6OiYvFikshyaQaCN
#
#    is_local  is_playable           name  popularity  \
# 0     False         True       Everlong          82
# 1     False         True  The Pretender          76
# 2     False         True   Learn to Fly          74
# 3     False         True    Best of You          73
# 4     False         True        My Hero          73
#
#                                          preview_url  track_number   type  \
# 0  https://p.scdn.co/mp3-preview/78fd3872e0fa5940...            11  track
# 1  https://p.scdn.co/mp3-preview/23a6ace367943106...             1  track
# 2  https://p.scdn.co/mp3-preview/410537fea88c9d30...             3  track
# 3  https://p.scdn.co/mp3-preview/663c0b487fce5c98...             3  track
# 4  https://p.scdn.co/mp3-preview/5ffdbc197d59a4bc...             7  track
#
#                                     uri
# 0  spotify:track:5UWwZ5lm5PKu6eKsHAGxOk
# 1  spotify:track:7x8dCjCr0x6x2lXKujYD34
# 2  spotify:track:5OQsiBsky2k2kDKy2bX2eT
# 3  spotify:track:5FZxsHWIvUsmSK1IAvm2pp
# 4  spotify:track:4dVbhS6OiYvFikshyaQaCN
